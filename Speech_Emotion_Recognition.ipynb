# %% [markdown]
# # **Speech Emotion Recognition**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # **Classification Algorithm - Different Dataset**

# %% [markdown]
# **Classification of RAVDESS Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/ravdess.csv')

data = shuffle(data)

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

label = ['ANG', 'CALM', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']
#label = ['ANG', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']

#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)


from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
cm = confusion_matrix(y_test,y_predict)
cf_matrix = pd.DataFrame(cm)


sns.set(font_scale = 1.0)
#sns.heatmap(cf_matrix, annot=True, cbar = True, linecolor = "grey", linewidth = .5)
sns.set(font_scale=1.3)
sns.heatmap(cf_matrix, annot=True, cmap='Greens', fmt = '.0f', cbar = True, linecolor = "grey", linewidth = .5, xticklabels = label, yticklabels = label)
#sns.heatmap(cf_matrix, annot = True)
plt.ylabel("True label", size = 15, fontweight='bold')
plt.xlabel("Predicted label", size = 15, fontweight='bold')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-01-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-01-10234.eps", dpi=500, bbox_inches='tight')
plt.show()



print('********Classification Report********')
print(classification_report(y_test, y_predict))


acc = float(accuracy_score(y_test,y_predict))*100
print("Accuracy score : %s  " % acc)

train_acc = float(model.score(X_train, y_train)*100)
print("Train accuracy score : %s  " % train_acc)

test_acc = float(model.score(X_test, y_test)*100)
print("Test accuracy score : %s " % test_acc)
# Out:
# ********Classification Report********
#               precision    recall  f1-score   support
#
#          ANG       0.97      1.00      0.99        68
#         CALM       1.00      1.00      1.00        77
#          DIS       0.97      0.97      0.97        37
#         FEAR       1.00      1.00      1.00        79
#          HAP       1.00      0.97      0.99        75
#          NEU       1.00      1.00      1.00        40
#          SAD       1.00      0.99      0.99        73
#          SUR       0.95      0.98      0.96        42
#
#     accuracy                           0.99       491
#    macro avg       0.99      0.99      0.99       491
# weighted avg       0.99      0.99      0.99       491
#
# Accuracy score : 98.98167006109979
# Train accuracy score : 100.0
# Test accuracy score : 98.98167006109979

# %% [markdown]
# **Classification of TESS Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from sklearn import svm
from sklearn.model_selection import train_test_split
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/tess.csv')

data = shuffle(data)

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

#label = ['ANG', 'CALM', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']
label = ['ANG', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']

#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)


from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
cm = confusion_matrix(y_test,y_predict)
cf_matrix = pd.DataFrame(cm)


sns.set(font_scale = 1.0)
#sns.heatmap(cf_matrix, annot=True, cbar = True, linecolor = "grey", linewidth = .5)
sns.set(font_scale=1.3)
sns.heatmap(cf_matrix, annot=True, cmap='Greens', fmt = '.0f', cbar = True, linecolor = "grey", linewidth = .5, xticklabels = label, yticklabels = label)
#sns.heatmap(cf_matrix, annot = True)
plt.ylabel("True label", size = 15, fontweight='bold')
plt.xlabel("Predicted label", size = 15, fontweight='bold')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-03-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-03-10234.eps", dpi=500, bbox_inches='tight')
plt.show()



print('********Classification Report********')
print(classification_report(y_test, y_predict))


acc = float(accuracy_score(y_test,y_predict))*100
print("Accuracy score : %s  " % acc)

train_acc = float(model.score(X_train, y_train)*100)
print("Train accuracy score : %s  " % train_acc)

test_acc = float(model.score(X_test, y_test)*100)
print("Test accuracy score : %s " % test_acc)
# Out:
# ********Classification Report********
#               precision    recall  f1-score   support
#
#          ANG       1.00      1.00      1.00        97
#          DIS       1.00      1.00      1.00        70
#         FEAR       1.00      1.00      1.00        81
#          HAP       1.00      0.99      0.99        78
#          NEU       1.00      1.00      1.00        83
#          SAD       1.00      1.00      1.00        73
#          SUR       0.99      1.00      0.99        78
#
#     accuracy                           1.00       560
#    macro avg       1.00      1.00      1.00       560
# weighted avg       1.00      1.00      1.00       560
#
# Accuracy score : 99.82142857142857
# Train accuracy score : 100.0
# Test accuracy score : 99.82142857142857

# %% [markdown]
# **Classification of SAVEE Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from sklearn import svm
from sklearn.model_selection import train_test_split
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/savee.csv')

data = shuffle(data)

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

#label = ['ANG', 'CALM', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']
label = ['ANG', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']

#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)


from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
cm = confusion_matrix(y_test,y_predict)
cf_matrix = pd.DataFrame(cm)


sns.set(font_scale = 1.0)
#sns.heatmap(cf_matrix, annot=True, cbar = True, linecolor = "grey", linewidth = .5)
sns.set(font_scale=1.3)
sns.heatmap(cf_matrix, annot=True, cmap='Greens', fmt = '.0f', cbar = True, linecolor = "grey", linewidth = .5, xticklabels = label, yticklabels = label)
#sns.heatmap(cf_matrix, annot = True)
plt.ylabel("True label", size = 15, fontweight='bold')
plt.xlabel("Predicted label", size = 15, fontweight='bold')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-04-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-04-10234.eps", dpi=500, bbox_inches='tight')
plt.show()



print('********Classification Report********')
print(classification_report(y_test, y_predict))


acc = float(accuracy_score(y_test,y_predict))*100
print("Accuracy score : %s  " % acc)

train_acc = float(model.score(X_train, y_train)*100)
print("Train accuracy score : %s  " % train_acc)

test_acc = float(model.score(X_test, y_test)*100)
print("Test accuracy score : %s " % test_acc)
# Out:
# ********Classification Report********
#               precision    recall  f1-score   support
#
#          ANG       0.86      1.00      0.93        19
#          DIS       1.00      1.00      1.00         8
#         FEAR       1.00      1.00      1.00        11
#          HAP       1.00      0.81      0.90        16
#          NEU       1.00      1.00      1.00        20
#          SAD       1.00      1.00      1.00        12
#          SUR       1.00      1.00      1.00        10
#
#     accuracy                           0.97        96
#    macro avg       0.98      0.97      0.97        96
# weighted avg       0.97      0.97      0.97        96
#
# Accuracy score : 96.875
# Train accuracy score : 100.0
# Test accuracy score : 96.875

# %% [markdown]
# **Classification of Combined Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from sklearn import svm
from sklearn.model_selection import train_test_split
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/CombinedDataset.csv')

data = shuffle(data)

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

label = ['ANG', 'CALM', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']
#label = ['ANG', 'DIS', 'FEAR', 'HAP', 'NEU', 'SAD', 'SUR']

#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)


from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
cm = confusion_matrix(y_test,y_predict)
cf_matrix = pd.DataFrame(cm)


sns.set(font_scale = 1.0)
#sns.heatmap(cf_matrix, annot=True, cbar = True, linecolor = "grey", linewidth = .5)
sns.set(font_scale=1.3)
sns.heatmap(cf_matrix, annot=True, cmap='Greens', fmt = '.0f', cbar = True, linecolor = "grey", linewidth = .5, xticklabels = label, yticklabels = label)
#sns.heatmap(cf_matrix, annot = True)
plt.ylabel("True label", size = 15, fontweight='bold')
plt.xlabel("Predicted label", size = 15, fontweight='bold')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-02-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig05-02-10234.eps", dpi=500, bbox_inches='tight')
plt.show()


print('********Classification Report********')
print(classification_report(y_test, y_predict))


acc = float(accuracy_score(y_test,y_predict))*100
print("Accuracy score : %s  " % acc)

train_acc = float(model.score(X_train, y_train)*100)
print("Train accuracy score : %s  " % train_acc)

test_acc = float(model.score(X_test, y_test)*100)
print("Test accuracy score : %s " % test_acc)
# Out:
# ********Classification Report********
#               precision    recall  f1-score   support
#
#          ANG       1.00      1.00      1.00       160
#         CALM       1.00      1.00      1.00        77
#          DIS       1.00      1.00      1.00       130
#         FEAR       1.00      1.00      1.00       159
#          HAP       1.00      1.00      1.00       197
#          NEU       1.00      1.00      1.00       122
#          SAD       1.00      1.00      1.00       168
#          SUR       1.00      1.00      1.00       134
#
#     accuracy                           1.00      1147
#    macro avg       1.00      1.00      1.00      1147
# weighted avg       1.00      1.00      1.00      1147
#
# Accuracy score : 100.0
# Train accuracy score : 100.0
# Test accuracy score : 100.0

# %% [markdown]
# # **Comparison - Different Datasets**

# %% [markdown]
# **Comparison among different datasets - Barchart**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd



# input data

"""Comparing three dataset and their combination based on """
data = {'Dataset':     ['RAVDESS', 'TESS', 'SAVEE', 'Combined Dataset'],
        'Accuracy':    [99.59, 99.82, 98.95, 100],
        'Precision':   [99.75, 99.86, 98.86, 100],
        'Recall':      [99.50, 99.86, 98.89, 100],
        'F1-score':    [99.50, 99.71, 98.86, 100]
       }



# make a dataframe
data = pd.DataFrame(data, columns=['Dataset', 'Accuracy', 'Precision', 'Recall', 'F1-score'])


data_M = pd.melt(data, id_vars='Dataset', var_name='Metrics', value_name='Score')

# Create an array with the colors you want to use
sns.set(style="dark")

sns.set_palette(sns.color_palette('tab10'))

sns.barplot(x="Metrics", y="Score", hue="Dataset", data=data_M)

plt.ylim(90, 101)


#plt.xticks(rotation = 45, ha = 'right')
#plt.legend(title = 'Dataset', bbox_to_anchor = (1, 1))
plt.legend(title = 'Dataset', loc = 'upper center', ncol = 2, bbox_to_anchor = (0.5, 1.20))

plt.ylabel("Score (%)", size = 15, fontweight='bold')
plt.xlabel("Metrics", size = 15, fontweight='bold' )
#plt.title("Precision of three different dataset")

#plt.savefig("Comparison.png")
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig04-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig04-10234.eps", dpi=500, bbox_inches='tight')
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # **Comparison with State-of-the-arts Methods**

# %% [markdown]
# **Import Libraries**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set(font_scale = 1.22)
#sns.set_style("white", {'axes.grid' : False})
sns.set_style("white")

# %% [markdown]
# **RAVDESS DATASET**

# %%
# input data

"""RAVDESS"""
Method = ['Proposed',  'ANN+PSO',  'DCNN', 'CNN', 'NN', 'SVM']
Accuracy = [98.47, 88.7, 75.83, 64.41, 89.16, 75.69]
percentage = [64.41, 75.69, 75.83, 88.7, 89.16, 99.59]


# make a dataframe
data = pd.DataFrame({"Method": Method,
                   "Accuracy": Accuracy})
data.sort_values('Accuracy')
print(data)
plots = sns.barplot(x="Method", y="Accuracy", data=data, order=data.sort_values('Accuracy').Method)

#plt.xticks(rotation = 45, ha = 'right')

plt.ylim(0, 106)
ax =sns.barplot(x="Method", y="Accuracy", data=data, order=data.sort_values('Accuracy').Method)

for bar in plots.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig07-10234.eps", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig07-10234.pdf", dpi=500, bbox_inches='tight')
plt.show()
# Out:
#      Method  Accuracy
# 0  Proposed     98.47
# 1   ANN+PSO     88.70
# 2      DCNN     75.83
# 3       CNN     64.41
# 4        NN     89.16
# 5       SVM     75.69

# %% [markdown]
# **TESS DATASET**

# %%
"""TESS"""
Method = ['Proposed',  'DCNN',  'CNN+AE', 'SVM+AE', 'DT+AE']
Accuracy = [99.49, 55.71, 96, 91.99, 90]
percentage = [55.71, 90, 91.99, 96, 99.82]


# make a dataframe
data = pd.DataFrame({"Method": Method,
                   "Accuracy": Accuracy})
data.sort_values('Accuracy')
print(data)
plots = sns.barplot(x="Method", y="Accuracy", data=data, order=data.sort_values('Accuracy').Method)

#plt.xticks(rotation = 45, ha = 'right')

plt.ylim(0, 107)
ax =sns.barplot(x="Method", y="Accuracy", data=data, order=data.sort_values('Accuracy').Method)

for bar in plots.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')


plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig08-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig08-10234.eps", dpi=500, bbox_inches='tight')
plt.show()
# Out:
#      Method  Accuracy
# 0  Proposed     99.49
# 1      DCNN     55.71
# 2    CNN+AE     96.00
# 3    SVM+AE     91.99
# 4     DT+AE     90.00

# %% [markdown]
# **SAVEE DATASET**

# %%
"""SAVEE"""
Method = ['Proposed',  'DCNN', 'SVM']
Accuracy = [97.12, 65.83, 77.4]
percentage = [65.83, 77.4, 98.95]


# make a dataframe
data = pd.DataFrame({"Method": Method,
                   "Accuracy": Accuracy})
data.sort_values('Accuracy')
print(data)
plots = sns.barplot(x="Method", y="Accuracy", data=data, order=data.sort_values('Accuracy').Method)

#plt.xticks(rotation = 45, ha = 'right')

plt.ylim(0, 105)
ax =sns.barplot(x="Method", y="Accuracy", data=data, order=data.sort_values('Accuracy').Method)


for bar in plots.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')


plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig09-10234.eps", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig09-10234.pdf", dpi=500, bbox_inches='tight')
plt.show()
# Out:
#      Method  Accuracy
# 0  Proposed     97.12
# 1      DCNN     65.83
# 2       SVM     77.40

# %% [markdown]
# **COMBINED DATASET**

# %% [markdown]
# # **ROC Curve - Different Datasets**

# %% [markdown]
# **ROC of RAVDESS**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle


import numpy as np
from sklearn.metrics import roc_curve,auc
from scipy import interp
from itertools import cycle
from sklearn.model_selection import train_test_split
from sklearn import svm

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/ravdess.csv')

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)
data = shuffle(data)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

n_classes=8



#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
pred1 = model.predict(X_test)


### MACRO
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(pred1))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'yellow', 'blue', 'magenta', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
#plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate (1-Specificity)', size = 18)
plt.ylabel('True Positive Rate (Sensitivity)', size = 18)
plt.title('ROC Curve Analysis', fontsize=18)
plt.legend(loc="lower right",  fontsize=15)
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-01-10234.eps", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-01-10234.pdf", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-78-2fe1d88d8177>:72: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# **ROC of TESS**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle


import numpy as np
from sklearn.metrics import roc_curve,auc
from scipy import interp
from itertools import cycle
from sklearn.model_selection import train_test_split
from sklearn import svm

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/tess.csv')

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)
data = shuffle(data)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

n_classes=7



#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
pred1 = model.predict(X_test)


### MACRO
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(pred1))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'yellow', 'blue', 'magenta', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
#plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate (1-Specificity)', size = 18)
plt.ylabel('True Positive Rate (Sensitivity)', size = 18)
plt.title('ROC Curve Analysis', fontsize=18)
plt.legend(loc="lower right",  fontsize=15)
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-02-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-02-10234.eps", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-79-f3e7a6ecdff9>:72: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# **ROC of SAVEE**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle


import numpy as np
from sklearn.metrics import roc_curve,auc
from scipy import interp
from itertools import cycle
from sklearn.model_selection import train_test_split
from sklearn import svm

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/savee.csv')

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)
data = shuffle(data)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

n_classes=7



#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
pred1 = model.predict(X_test)


### MACRO
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(pred1))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'yellow', 'blue', 'magenta', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
#plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate (1-Specificity)', size = 18)
plt.ylabel('True Positive Rate (Sensitivity)', size = 18)
plt.title('ROC Curve Analysis', fontsize=18)
plt.legend(loc="lower right",  fontsize=15)
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-03-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-03-10234.eps", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-80-20e49f3f21ed>:72: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# **ROC of Combined Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle


import numpy as np
from sklearn.metrics import roc_curve,auc
from scipy import interp
from itertools import cycle
from sklearn.model_selection import train_test_split
from sklearn import svm

#reading csv file
data = pd.read_csv('/content/gdrive/MyDrive/SER/DATASET CSV FILE/CombinedDataset.csv')

#dropping the column Unnamed: 0 to removed shuffled index
data = data.drop('Unnamed: 0',axis=1)
data = shuffle(data)

#separating features and target outputs
X = data.drop('emotion', axis = 1).values
y = data['emotion'].values

n_classes=8



#train test spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 4)

#svm model
model = svm.SVC(kernel='linear', gamma='auto', C=2)
model.fit(X_train, y_train)
pred1 = model.predict(X_test)


### MACRO
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(pred1))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'yellow', 'blue', 'magenta', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
#plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate (1-Specificity)', size = 18)
plt.ylabel('True Positive Rate (Sensitivity)', size = 18)
plt.title('ROC Curve Analysis', fontsize=18)
plt.legend(loc="lower right",  fontsize=15)
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-04-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig06-04-10234.eps", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-81-326d9c761ade>:72: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # **ROC-AUC**

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html

# %% [markdown]
# https://www.kaggle.com/code/nkitgupta/evaluation-metrics-for-multi-class-classification

# %% [markdown]
# # **Waveform of Different Classes**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# IMPORT NECESSARY LIBRARIES
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import numpy as np
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
import os # interface with underlying OS that python is running on
import sys
import warnings
# ignore warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization, Dense
from sklearn.model_selection import GridSearchCV
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# %% [markdown]
# # **File naming convention**

# %% [markdown]
# **File naming convention**
#
# Each of the 1440 files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 03-01-06-01-02-01-12.wav). These identifiers define the stimulus characteristics:
#
# **Filename identifiers**
#
# Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# Vocal channel (01 = speech, 02 = song).
#
# Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# **Filename example:** 03-01-06-01-02-01-12.wav
#
# Audio-only (03)
#
# Speech (01)
#
# Fearful (06)
#
# Normal intensity (01)
#
# Statement "dogs" (02)
#
# 1st Repetition (01)
#
# 12th Actor (12)
#
# Female, as the actor ID number is even.

# %% [markdown]
# # **Testing**

# %%
# LOAD FILE ANGRY
xa, sra = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-05-01-01-02-03.wav')

# LOAD FILE CALM
xc, src = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-02-02-01-02-03.wav')

# LOAD FILE DISGUST
xd, srd = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-07-01-02-01-03.wav')

# LOAD FILE FEAR
xf, srf = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-06-02-02-01-03.wav')

# LOAD FILE HAPPY
xh, srh = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-03-01-02-01-03.wav')

# LOAD FILE NEUTRAL
xn, srn = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-01-01-01-01-03.wav')

# LOAD FILE SAD
xs, srs = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-04-01-01-02-03.wav')

# LOAD FILE SURPRISE
xsu, srsu = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-08-01-02-01-03.wav')

# %%
from typing import SupportsRound
# Make a new figure
plt.figure(figsize=(16,8))

plt.subplot(2,4,1)
# Display the spectrogram on a mel scale
librosa.display.waveshow(xa, sr=sra)


# Put a descriptive title on the plot
plt.title('ANGRY')


plt.subplot(2,4,2)
librosa.display.waveshow(xc, sr=src)


# Put a descriptive title on the plot
plt.title('CALM')

plt.subplot(2,4,3)
# Display the spectrogram on a mel scale
librosa.display.waveshow(xd, sr=srd)


# Put a descriptive title on the plot
plt.title('DISGUST')


plt.subplot(2,4,4)
librosa.display.waveshow(xf, sr=srf)

# Put a descriptive title on the plot
plt.title('FEAR')

plt.subplot(2,4,5)
# Display the spectrogram on a mel scale
librosa.display.waveshow(xh, sr=srh)


# Put a descriptive title on the plot
plt.title('HAPPY')


plt.subplot(2,4,6)
librosa.display.waveshow(xn, sr=srn)


# Put a descriptive title on the plot
plt.title('NEUTRAL')

plt.subplot(2,4,7)
# Display the spectrogram on a mel scale
librosa.display.waveshow(xs, sr=srs)


# Put a descriptive title on the plot
plt.title('SAD')


plt.subplot(2,4,8)
librosa.display.waveshow(xsu, sr=srsu)


# Put a descriptive title on the plot
plt.title('SURPRISE')

# Make the figure layout compact
plt.tight_layout()
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig03-10234.pdf", dpi=500, bbox_inches='tight')
plt.savefig("/content/gdrive/MyDrive/SER/OUTPUT/Fig03-10234.eps", dpi=500, bbox_inches='tight')

# %% [markdown]
# # **Class-0: Male ANGRY**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-05-01-01-02-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Angry', fontsize=15)
plt.savefig('Waveplot_MaleAngry.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Angry')
plt.savefig('MelSpec_MaleAngry.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-1: Male CALM**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-02-02-01-02-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male calm')
plt.savefig('Waveplot_MaleCalm.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Calm')
plt.savefig('MelSpec_MaleCalm.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-2: Male DISGUST**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-07-01-02-01-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Disgust')
plt.savefig('Waveplot_MaleHappy.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Disgust')
plt.savefig('MelSpec_MaleHappy.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-3: Male Fear**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-06-02-02-01-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Fear')
plt.savefig('Waveplot_MaleHappy.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Fear')
plt.savefig('MelSpec_MaleHappy.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-4: Male Happy**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-03-01-02-01-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Happy')
plt.savefig('Waveplot_MaleHappy.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Happy')
plt.savefig('MelSpec_MaleHappy.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-5: Male Neutral**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-01-01-01-01-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Neutral')
plt.savefig('Waveplot_MaleHappy.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Neutral')
plt.savefig('MelSpec_MaleHappy.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-6: Male Sad**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-04-01-01-02-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Sad')
plt.savefig('Waveplot_MaleHappy.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Sad')
plt.savefig('MelSpec_MaleHappy.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# # **Class-7: Male Surprise**

# %%
# LOAD FILE
x, sr = librosa.load('/content/gdrive/MyDrive/SER/DATASET/AUDIO_SPEECH/Actor_03/03-01-08-01-02-01-03.wav')

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveshow(x, sr=sr)
plt.title('Waveplot - Male Surprise')
plt.savefig('Waveplot_MaleHappy.png')

# %%
# CREATE LOG MEL SPECTROGRAM
x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
x = librosa.power_to_db(x)

librosa.display.specshow(x, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Surprise')
plt.savefig('MelSpec_MaleHappy.png')
plt.colorbar(format='%+2.0f dB');
